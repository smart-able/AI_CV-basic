# %% [markdown]
# <a href="https://colab.research.google.com/github/smart-able/AI_CV-basic/blob/main/bicycle_RGB2HSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
src_rgb = cv2.imread('bicycle.png', cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(src_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=2045x1534 at 0x7FB176210F10>

# %%
#high [255, 213, 58]
#low [221, 195, 5]

# %%
import numpy as np

# %%
high_yellow = np.array([255, 213, 58])
low_yellow = np.array([221, 195, 5])

# %%
mask = cv2.inRange(src_rgb, low_yellow, high_yellow)

# %%
result_src=cv2.bitwise_and(src, src, mask=mask )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-561f230ffe3e> in <module>
# ----> 1 result_src=cv2.bitwise_and(src, src, mask=mask )
#
# NameError: name 'src' is not defined

# %%
cv2_imshow(result_src)

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
src = cv2.imread('bicycle.png',cv2.IMREAD_UNCHANGED)

# %%
src_hsv = cv2.cvtColor(src,cv2.COLOR_BGR2HSV)

# %%
low_yellow = np.array([25, 127, 0])
high_yellow = np.array([255, 255, 255])

# %%
mask = cv2.inRange(src_hsv, low_yellow, high_yellow)

# %%
result_src=cv2.bitwise_and(src,src,mask=mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534 at 0x7FB1603A70D0>
