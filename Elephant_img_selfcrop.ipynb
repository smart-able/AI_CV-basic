# %% [markdown]
# <a href="https://colab.research.google.com/github/smart-able/AI_CV-basic/blob/main/Elephant_img_selfcrop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install opencv-python==4.4.0.46

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow #코랩에서만 쓰는 이미지 오픈cv라이브러리

# %%
cv2.__version__
# Out:
# '4.6.0'

# %%
src=cv2.imread('elephant2.png')

# %%
type(src)
# Out:
# numpy.ndarray

# %%
src.shape #튜플형식
# Out:
# (532, 946, 3)

# %%
height, width, channel= src.shape

# %%
height
# Out:
# 532

# %%
width
# Out:
# 946

# %%
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=946x532 at 0x7F7730B1D750>

# %%
elephant1=src[70:500,250:830] #이미지 자르기, 세로,가로 범위지정

# %%
cv2_imshow(elephant1)
# Out:
# <PIL.Image.Image image mode=RGB size=580x430 at 0x7F7730A66310>

# %%
elephant2=src[170:320,73:210]

# %%
cv2_imshow(elephant2)
# Out:
# <PIL.Image.Image image mode=RGB size=137x150 at 0x7F7727292150>
